# %%
import ipywidgets as widgets
import pandas as pd  # wheel file for pandas may be required
import json
pd.options.display.max_rows = None
pd.options.display.max_columns = None
from IPython.core.display import display, HTML
out = widgets.Output(layout={'border': '1px solid black'})

# %%
xls = pd.ExcelFile('Book1.xls')
df1 = pd.read_excel(xls, 'Sheet1',index = True)
df2 = pd.read_excel(xls, 'Sheet2',index = True)
#increase df's for number of sheets

# %%
def simple_generator_function(df):
    global count
    count=0
    while(count < len(df)): 
        yield ("banana",df.loc[count]['banana'])
 
def on_button_clicked_1(b1):
    global flag
    global count
    df1.loc[count,'label'] = 0 # change df1 to dfn here
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)
    
def on_button_clicked_2(b2):
    global flag
    global count
    df1.loc[count,'label'] = 1  # change df1 to dfn here
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)
def on_button_clicked_3(b3):
    global flag
    global count
    df1.loc[count,'label'] = 2 # change df1 to dfn here
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)

def on_button_clicked_4(b4):
    global flag
    global count
    df1.loc[count,'label'] = 3 # change df1 to dfn here
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)

def on_button_clicked_5(b5):
    global flag
    global count
    df1.loc[count,'label'] = 4 # change df1 to dfn here
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)
        
def on_button_clicked_6(b6):
    global flag
    global count
    df1.loc[count,'label'] = 5 # change df1 to dfn here
    print(df1)
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)


def on_button_clicked_7(b7):
    global flag
    global count
    df1.loc[count,'label'] = 6 # change df1 to dfn here
    print(df1)
    count+=1
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("Finished")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)
        

def on_button_clicked_Start(b8):
    global flag
    out.clear_output()
    try:
        print(next(our_generator))
    except StopIteration:
        flag = 1
        print("No Data")
    if not flag:
        display(button_1)
        display(button_2)
        display(button_3)
        display(button_4)
        display(button_5)
        display(button_6)
        display(button_7)
    
    
our_generator = simple_generator_function(df1) # change df1 to dfn here

with out:
    flag = 0
    pair_number = None
    start_button = widgets.Button(description = "Start")
    button_1 = widgets.Button(description = "0")
    button_2 = widgets.Button(description = "1")
    button_3 = widgets.Button(description = "2")
    button_4 = widgets.Button(description = "3")
    button_5 = widgets.Button(description = "4")
    button_6 = widgets.Button(description = "5")
    button_7 = widgets.Button(description = "6")            
    display(start_button)
    start_button.on_click(on_button_clicked_Start)
    button_1.on_click(on_button_clicked_1)
    button_2.on_click(on_button_clicked_2)
    button_3.on_click(on_button_clicked_3)
    button_4.on_click(on_button_clicked_4)
    button_5.on_click(on_button_clicked_5)
    button_6.on_click(on_button_clicked_6)
    button_7.on_click(on_button_clicked_7)

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %%
out
# Out:
# Output(layout=Layout(border='1px solid black'), outputs=({'output_type': 'display_data', 'data': {'text/plain'…

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# ## Stop untill all the sheets are annotated

# %%
#writing the results on new excel file

# %%
# only run when all the df(thus sheets are done annotating)
with pd.ExcelWriter('output.xls') as writer:  
    df1.to_excel(writer, sheet_name='Sheet1')
    df2.to_excel(writer, sheet_name='Sheet2')
